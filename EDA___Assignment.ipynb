# %% [markdown]
# Question 1: Read the Bike Details dataset into a Pandas DataFrame and display its
# first 10 rows.

# %%
import pandas as pd
import gdown

# Step 1: Download the file from Google Drive
file_id = "1iKy23bMtEQShF_weneRNnYrFmzvpPOI3"
url = f"https://drive.google.com/uc?id={file_id}"
output = "bike_details.csv"  # or .xlsx if it's an Excel file
gdown.download(url, output, quiet=False)

# Step 2: Read the dataset
df = pd.read_csv(output)  # use pd.read_excel(output) if it's Excel

# Step 3: Display first 10 rows
print("First 10 rows:")
print(df.head(10))

# Step 4: Display shape and column names
print("\nShape of dataset:", df.shape)
print("Column names:", df.columns.tolist())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3
# To: /content/bike_details.csv
# 100%|██████████| 66.5k/66.5k [00:00<00:00, 41.8MB/s]
# First 10 rows:
#                                    name  selling_price  year seller_type  \
# 0             Royal Enfield Classic 350         175000  2019  Individual
# 1                             Honda Dio          45000  2017  Individual
# 2   Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# 5                      Honda CB Twister          18000  2010  Individual
# 6                  Honda CB Hornet 160R          78500  2018  Individual
# 7  Royal Enfield Bullet 350 [2007-2011]         180000  2008  Individual
# 8                Hero Honda CBZ extreme          30000  2010  Individual
# ...

# %% [markdown]
# Question 2: Check for missing values in all columns and describe your approach for
# handling them.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('bike_details.csv')  # Adjust the path if necessary

# Check for missing values in each column
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %% [markdown]
# Question 3: Plot the distribution of selling prices using a histogram and describe the
# overall trend.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
print(df.head())
# Set the style for the plots
sns.set(style="whitegrid")

# Create a histogram to visualize the distribution of selling prices
plt.figure(figsize=(10, 6))
sns.histplot(df['selling_price'], bins=30, kde=True, color='blue')
plt.title('Distribution of Selling Prices', fontsize=15)
plt.xlabel('Selling Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %% [markdown]
# Question 4: Create a bar plot to visualize the average selling price for each seller_type
# and write one observation.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
print(df.head())
# Set the style for the plots
sns.set(style="whitegrid")

# Create a bar plot to visualize the average selling price by seller type
plt.figure(figsize=(10, 6))
sns.barplot(x='seller_type', y='selling_price', data=df, estimator='mean', palette='viridis')

# Add titles and labels
plt.title('Average Selling Price by Seller Type', fontsize=15)
plt.xlabel('Seller Type', fontsize=12)
plt.ylabel('Average Selling Price', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN
# /tmp/ipython-input-4061963532.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Question 5: Compute the average km_driven for each ownership type (1st owner,
# 2nd owner, etc.), and present the result as a bar plot.

# %%
import pandas as pd

# Load the dataset from the provided Google Drive link
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
print(df.head())
# Group by ownership type and compute the mean of km_driven
avg_km_by_owner = df.groupby('owner')['km_driven'].mean().reset_index()

# Sort the values for better visualization
avg_km_by_owner = avg_km_by_owner.sort_values('km_driven', ascending=False)
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style for the plots
sns.set(style="whitegrid")

# Create a bar plot to visualize the average km_driven by ownership type
plt.figure(figsize=(10, 6))
sns.barplot(x='owner', y='km_driven', data=avg_km_by_owner, palette='viridis')

# Add titles and labels
plt.title('Average Kilometers Driven by Ownership Type', fontsize=15)
plt.xlabel('Ownership Type', fontsize=12)
plt.ylabel('Average Kilometers Driven', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN
# /tmp/ipython-input-452473718.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Question 6: Use the IQR method to detect and remove outliers from the km_driven
# column. Show before-and-after summary statistics

# %%
import pandas as pd

# Load the dataset from the provided Google Drive link
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
# Display the first few rows to understand its structure
print(df.head())

# Check the column names to identify the relevant one for kilometers driven
print(df.columns)
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style for the plots
sns.set(style="whitegrid")

# Create a box plot to visualize the distribution of km_driven
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['km_driven'])
plt.title('Distribution of km_driven Before Removing Outliers', fontsize=15)
plt.xlabel('Kilometers Driven', fontsize=12)
plt.tight_layout()
plt.show()
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['km_driven'] < lower_bound) | (df['km_driven'] > upper_bound)]
print(f"Number of outliers detected: {len(outliers)}")
# Remove rows containing outliers
df_cleaned = df[(df['km_driven'] >= lower_bound) & (df['km_driven'] <= upper_bound)]

# Display the shape of the original and cleaned datasets
print(f"Original dataset shape: {df.shape}")
print(f"Cleaned dataset shape: {df_cleaned.shape}")
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')
# Number of outliers detected: 39
# Original dataset shape: (1061, 7)
# Cleaned dataset shape: (1022, 7)

# %% [markdown]
# Question 7: Create a scatter plot of year vs. selling_price to explore the
# relationship between a bike's age and its price

# %%
import pandas as pd

# Load the dataset from the provided Google Drive link
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
# Display the first few rows to understand its structure
print(df.head())

# Check the column names to identify the relevant ones for year and selling price
print(df.columns)
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style for the plots
sns.set(style="whitegrid")

# Create a scatter plot to visualize the relationship between year and selling price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='year', y='selling_price', data=df, color='blue', alpha=0.6)

# Add titles and labels
plt.title('Scatter Plot: Year vs. Selling Price', fontsize=15)
plt.xlabel('Year of Manufacture', fontsize=12)
plt.ylabel('Selling Price', fontsize=12)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %% [markdown]
# Question 8: Convert the seller_type column into numeric format using one-hot
# encoding. Display the first 5 rows of the resulting DataFrame.

# %%
import pandas as pd

# Load the dataset from Google Drive
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
# One-hot encode the 'seller_type' column
seller_encoded = pd.get_dummies(df['seller_type'], prefix='seller')

# Concatenate the encoded columns with the original DataFrame
df_encoded = pd.concat([df, seller_encoded], axis=1)

# Drop the original 'seller_type' column if desired
df_encoded.drop('seller_type', axis=1, inplace=True)
print(df_encoded.head())
# Out:
#                                   name  selling_price  year      owner  \
# 0            Royal Enfield Classic 350         175000  2019  1st owner
# 1                            Honda Dio          45000  2017  1st owner
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  1st owner
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  1st owner
# 4                Yamaha SZ [2013-2014]          20000  2011  2nd owner
#
#    km_driven  ex_showroom_price  seller_Dealer  seller_Individual
# 0        350                NaN          False               True
# 1       5650                NaN          False               True
# 2      12000           148114.0          False               True
# 3      23000            89643.0          False               True
# 4      21000                NaN          False               True

# %% [markdown]
# Question 9: Generate a heatmap of the correlation matrix for all numeric columns.
# What correlations stand out the most?

# %%
import pandas as pd

# Load the dataset from the provided Google Drive link
url = 'https://drive.google.com/uc?id=1iKy23bMtEQShF_weneRNnYrFmzvpPOI3'
df = pd.read_csv(url)
# Display the first few rows to understand its structure
print(df.head())

# Check the column names to identify the relevant ones for correlation analysis
print(df.columns)
# Compute the correlation matrix for numeric columns
corr_matrix = df.corr()
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Set the style for the plots
sns.set(style="whitegrid")

# Create a mask to hide the upper triangle of the matrix
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, mask=mask, cmap=cmap, vmax=1, center=0,
            annot=True, fmt='.2f', annot_kws={"size": 10},
            square=True, linewidths=0.5, cbar_kws={"shrink": .8})

# Add title
plt.title('Correlation Heatmap of Numeric Columns', fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# Question 10: Summarize your findings in a brief report:
# ● What are the most important factors affecting a bike's selling price?
# ● Mention any data cleaning or feature engineering you performed.

# %% [markdown]
# Bike Age: Older bikes have lower prices.
#
# Seller Type: Dealer-sold bikes generally fetch higher prices than individual sellers.
#
# Kilometers Driven: Higher mileage → lower price.
#
# Ownership: First-owner bikes are priced higher.
#
# Brand/Model: Popular or premium models sell for more.
#
# Data Cleaning & Feature Engineering
#
# Missing Values: Numerical → median, Categorical → mode.
#
# Outliers: Removed using IQR in km_driven.
#
# Encoding: One-hot encoded seller_type.
#
# Feature Engineering: Created bike_age = 2025 - year.
