# %% [markdown]
# Question 1: What is hypothesis testing in statistics?
#
# ANS
# :- Hypothesis testing is like a court trial:
#
# H₀ = "Defendant is innocent."
#
# Evidence (data) is presented.
#
# If evidence is strong enough (p-value small), reject H₀ and conclude "defendant is guilty."

# %% [markdown]
# Question 2: What is the null hypothesis, and how does it differ from the alternative
# hypothesis?
#
# ANS
# | **Aspect**   | **Null Hypothesis (H₀)**          | **Alternative Hypothesis (H₁)**                  |
# | ------------ | --------------------------------- | ------------------------------------------------ |
# | **Meaning**  | No effect/difference/relationship | There is an effect/difference/relationship       |
# | **Role**     | Default assumption (to be tested) | Competing claim (to be supported if data agrees) |
# | **Symbol**   | H₀                                | H₁ or Ha                                         |
# | **Decision** | “Fail to reject” or “Reject”      | “Supported” if H₀ is rejected                    |
#
#
# H₀ = "Nothing is happening."
#
# H₁ = "Something is happening."

# %% [markdown]
# Question 3: Explain the significance level in hypothesis testing and its role in deciding
# the outcome of a test.
#
# ANS :- The significance level (α) is the cut-off line that helps us decide:
#
# Is the observed result just due to random chance (retain H₀)?
#
# Or is it strong enough evidence to reject H₀ and support H₁?

# %% [markdown]
# Question 4: What are Type I and Type II errors? Give examples of each.
#
# ANS
# | Error Type      | What happens?                                       | Real-world analogy                  |
# | --------------- | --------------------------------------------------- | ----------------------------------- |
# | **Type I (α)**  | Reject H₀ when H₀ is true (false positive)          | Declaring an innocent person guilty |
# | **Type II (β)** | Fail to reject H₀ when H₀ is false (false negative) | Letting a guilty person go free     |
#
#
# Type I = false alarm.
#
# Type II = missed detection.

# %% [markdown]
# Question 5: What is the difference between a Z-test and a T-test? Explain when to use
# each
#
# ANS
# Z-Test
#
# Used when:
#
# Sample size is large (n ≥ 30).
#
# Population standard deviation (σ) is known.
#
# Distribution: Standard Normal Distribution (Z-distribution).
#
# Formula (one-sample Z-test):
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# 	​
#
# X
# ˉ
# −μ
# 	​
#
#
# where
#
# 𝑋
# ˉ
# X
# ˉ
#  = sample mean
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
#
# T-Test
#
# Used when:
#
# Sample size is small (n < 30).
#
# Population standard deviation (σ) is unknown (we use sample standard deviation,
# 𝑠
# s).
#
# Distribution: Student’s t-distribution (heavier tails than normal).
#
# Formula (one-sample T-test):
#
# 𝑡
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# /
# 𝑛
# t=
# s/
# n
# 	​
#
# X
# ˉ
# −μ
# 	​
#
#
# where
#
# 𝑠
# s = sample standard deviation.
#
# | Feature               | **Z-Test**          | **T-Test**                                           |
# | --------------------- | ------------------- | ---------------------------------------------------- |
# | Sample Size           | Large (n ≥ 30)      | Small (n < 30)                                       |
# | Population Std. Dev.  | Known (σ available) | Unknown (use sample s)                               |
# | Distribution Used     | Standard Normal (Z) | Student’s t-distribution                             |
# | Shape of Distribution | Fixed (bell curve)  | Changes with sample size (heavier tails for small n) |
#
#
# Use a Z-test when sample is large and σ is known.
#
# Use a T-test when sample is small and σ is unknown.

# %% [markdown]
# Question 6: Write a Python program to generate a binomial distribution with n=10 and
# p=0.5, then plot its histogram.
#
# ANS

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10     # number of trials
p = 0.5    # probability of success
size = 1000  # number of samples

# Generate random samples from a binomial distribution
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(n+2), edgecolor='black', align='left')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.show()

# %% [markdown]
# Implement hypothesis testing using Z-statistics for a sample dataset in
# Python. Show the Python code and interpret the results.
# sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
# 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
# 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
# 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]
#
# ANS

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# Hypothesized population mean
mu_0 = 50

# Sample statistics
n = len(sample_data)
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)  # sample standard deviation

# Z-statistic calculation
z_stat = (sample_mean - mu_0) / (sample_std / np.sqrt(n))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print("Sample Mean:", sample_mean)
print("Sample Std Dev:", sample_std)
print("Z-statistic:", z_stat)
print("p-value:", p_value)

# Decision
alpha = 0.05
if p_value < alpha:
    print("Reject H0: Evidence suggests the mean is different from", mu_0)
else:
    print("Fail to Reject H0: Not enough evidence to say the mean is different from", mu_0)
# Out:
# Sample Mean: 50.08888888888889
# Sample Std Dev: 0.5365379910807955
# Z-statistic: 0.9940271559503017
# p-value: 0.3202096468890012
# Fail to Reject H0: Not enough evidence to say the mean is different from 50

# %% [markdown]
# Question 8: Write a Python script to simulate data from a normal distribution and
# calculate the 95% confidence interval for its mean. Plot the data using Matplotlib.
#
# ANS

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate data from a normal distribution
np.random.seed(42)  # for reproducibility
mu, sigma = 50, 5   # population mean and std dev
n = 100             # sample size
data = np.random.normal(mu, sigma, n)

# Step 2: Calculate sample mean and standard error
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
se = sample_std / np.sqrt(n)

# Step 3: Compute 95% confidence interval
confidence = 0.95
z_critical = stats.norm.ppf(1 - (1-confidence)/2)  # two-tailed
margin_of_error = z_critical * se
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print("Sample Mean:", sample_mean)
print("95% Confidence Interval:", (ci_lower, ci_upper))

# Step 4: Plot histogram of data
plt.hist(data, bins=15, edgecolor='black', alpha=0.7, density=True)
plt.axvline(sample_mean, color='red', linestyle='dashed', linewidth=2, label=f"Mean = {sample_mean:.2f}")
plt.axvline(ci_lower, color='blue', linestyle='dashed', linewidth=2, label=f"95% CI Lower = {ci_lower:.2f}")
plt.axvline(ci_upper, color='blue', linestyle='dashed', linewidth=2, label=f"95% CI Upper = {ci_upper:.2f}")
plt.title("Normal Distribution Sample with 95% Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend()
plt.show()
# Out:
# Sample Mean: 49.48076741302953
# 95% Confidence Interval: (np.float64(48.59077870763371), np.float64(50.370756118425355))

# %% [markdown]
# Question 9: Write a Python function to calculate the Z-scores from a dataset and
# visualize the standardized data using a histogram. Explain what the Z-scores represent
# in terms of standard deviations from the mean.
# ANS A Z-score tells us how many standard deviations a data point is away from the mean.
#
# Formula:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# 	​
#
#
# where
#
# 𝑋
# X = data point,
#
# 𝜇
# μ = mean of the dataset,
#
# 𝜎
# σ = standard deviation.
#
# Interpretation:
#
# Z = 0 → data point is exactly the mean.
#
# Z = +1 → one standard deviation above the mean.
#
# Z = -2 → two standard deviations below the mean.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std = np.std(data, ddof=1)  # sample standard deviation

    # Compute Z-scores
    z_scores = [(x - mean) / std for x in data]
    return np.array(z_scores)

# Example dataset
data = [10, 12, 13, 15, 16, 18, 20, 22, 23, 25]

# Calculate Z-scores
z_scores = calculate_z_scores(data)

print("Original Data:", data)
print("Z-scores:", z_scores)

# Plot histogram of Z-scores
plt.hist(z_scores, bins=10, edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='dashed', linewidth=2, label="Mean (Z=0)")
plt.title("Histogram of Standardized Data (Z-scores)")
plt.xlabel("Z-score (Standard Deviations)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Original Data: [10, 12, 13, 15, 16, 18, 20, 22, 23, 25]
# Z-scores: [-1.46894293 -1.07193133 -0.87342553 -0.47641392 -0.27790812  0.11910348
#   0.51611509  0.91312669  1.11163249  1.50864409]
